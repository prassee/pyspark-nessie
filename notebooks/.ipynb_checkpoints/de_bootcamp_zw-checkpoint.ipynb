# %%
# Import required libraries
import os
import sys
from pyspark.sql import SparkSession
from pyspark.sql.functions import current_timestamp, col, when, lit
from pyspark.sql.types import (
    StructType,
    StructField,
    StringType,
    IntegerType,
    DoubleType,
    TimestampType,
)

print("✅ Imports successful!")
print(f"Python version: {sys.version}")

# Set environment variables for better output
os.environ["PYSPARK_SUBMIT_ARGS"] = "--jars /opt/spark/jars-custom/*.jar pyspark-shell"
# Out:
# ✅ Imports successful!
# Python version: 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0]

# %%
spark = (
    SparkSession.builder.appName("IcebergNessieDemo")
    .config(
        "spark.sql.extensions",
        "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions",
    )
    .config("spark.sql.catalog.nessie", "org.apache.iceberg.spark.SparkCatalog")
    .config(
        "spark.sql.catalog.nessie.catalog-impl",
        "org.apache.iceberg.nessie.NessieCatalog",
    )
    .config("spark.sql.catalog.nessie.uri", "http://nessie:19120/api/v1")
    .config("spark.sql.catalog.nessie.ref", "main")
    .config("spark.sql.catalog.nessie.warehouse", "s3a://warehouse/")
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000")
    .config("spark.hadoop.fs.s3a.access.key", "admin")
    .config("spark.hadoop.fs.s3a.secret.key", "password")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config(
        "spark.hadoop.fs.s3a.aws.credentials.provider",
        "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider",
    )
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer")
    .getOrCreate()
)

# %%
print("✅ SparkSession created successfully!")
print(f"Spark version: {spark.version}")
print(f"Application ID: {spark.sparkContext.applicationId}")

# Set default catalog
spark.sql("USE nessie")
# Out:
# ✅ SparkSession created successfully!
# Spark version: 3.5.0
# Application ID: local-1751941979496
# DataFrame[]

# %%
spark.sql("CREATE NAMESPACE IF NOT EXISTS nessie.demo")
# Out:
# DataFrame[]

# %%
medals = spark.read.csv("s3a://sdc/medals.csv",header=True, inferSchema=True)
matches = spark.read.csv("s3a://sdc/matches.csv",header=True, inferSchema=True)
match_details = spark.read.csv("s3a://sdc/match_details.csv",header=True, inferSchema=True)
medals_matches_players = spark.read.csv("s3a://sdc/medals_matches_players.csv",header=True, inferSchema=True)

# %%
# match_details.printSchema()
match_details.write.bucketBy(16,"match_id").format("iceberg").mode("overwrite").saveAsTable("nessie.demo.match_details")

# %%
matches.write.bucketBy(16,"match_id").format("iceberg").mode("overwrite").saveAsTable("nessie.demo.matches")

# %%
medals.write.bucketBy(16,"medal_id").format("iceberg").mode("overwrite").saveAsTable("nessie.demo.medals")

# %%
medals_matches_players.write.bucketBy(16,"match_id").format("iceberg").mode("overwrite").saveAsTable("nessie.demo.medals_matches_players")

# %%
# matches.join(match_details,on="match_id").join(medals_matches_players,on="match_id").explain()
matches_table = spark.table("nessie.demo.matches")
match_details_table= spark.table("nessie.demo.match_details")
mmd_table = spark.table("nessie.demo.medals_matches_players")
matches_table.join(match_details_table,on="match_id").join(mmd_table,on="match_id").explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [match_id#706, mapid#707, is_team_game#708, playlist_id#709, game_variant_id#710, is_match_over#711, completion_date#712, match_duration#713, game_mode#714, map_variant_id#715, obs_year#716, obs_month#717, player_gamertag#731, previous_spartan_rank#732, spartan_rank#733, previous_total_xp#734, total_xp#735, previous_csr_tier#736, previous_csr_designation#737, previous_csr#738, previous_csr_percent_to_next_tier#739, previous_csr_rank#740, current_csr_tier#741, current_csr_designation#742, ... 26 more fields]
#    +- SortMergeJoin [match_id#706], [match_id#802], Inner
#       :- Sort [match_id#706 ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(match_id#706, 200), ENSURE_REQUIREMENTS, [plan_id=369]
#       :     +- Project [match_id#706, mapid#707, is_team_game#708, playlist_id#709, game_variant_id#710, is_match_over#711, completion_date#712, match_duration#713, game_mode#714, map_variant_id#715, obs_year#716, obs_month#717, player_gamertag#731, previous_spartan_rank#732, spartan_rank#733, previous_total_xp#734, total_xp#735, previous_csr_tier#736, previous_csr_designation#737, previous_csr#738, previous_csr_percent_to_next_tier#739, previous_csr_rank#740, current_csr_tier#741, current_csr_designation#742, ... 23 more fields]
#       :        +- BroadcastHashJoin [match_id#706], [match_id#730], Inner, BuildLeft, false
#       :           :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=364]
#       :           :  +- BatchScan nessie.demo.matches[match_id#706, mapid#707, is_team_game#708, playlist_id#709, game_variant_id#710, is_match_over#711, completion_date#712, match_duration#713, game_mode#714, map_variant_id#715, obs_year#716, obs_month#717] nessie.demo.matches (branch=null) [filters=match_id IS NOT NULL, groupedBy=] RuntimeFilters: []
#       :           +- BatchScan nessie.demo.match_details[match_id#730, player_gamertag#731, previous_spartan_rank#732, spartan_rank#733, previous_total_xp#734, total_xp#735, previous_csr_tier#736, previous_csr_designation#737, previous_csr#738, previous_csr_percent_to_next_tier#739, previous_csr_rank#740, current_csr_tier#741, current_csr_designation#742, current_csr#743, current_csr_percent_to_next_tier#744, current_csr_rank#745, player_rank_on_team#746, player_finished#747, player_average_life#748, player_total_kills#749, player_total_headshots#750, player_total_weapon_damage#751, player_total_shots_landed#752, player_total_melee_kills#753, ... 12 more fields] nessie.demo.match_details (branch=null) [filters=match_id IS NOT NULL, groupedBy=] RuntimeFilters: []
#       +- Sort [match_id#802 ASC NULLS FIRST], false, 0
#          +- Exchange hashpartitioning(match_id#802, 200), ENSURE_REQUIREMENTS, [plan_id=370]
#             +- BatchScan nessie.demo.medals_matches_players[match_id#802, player_gamertag#803, medal_id#804L, count#805] nessie.demo.medals_matches_players (branch=null) [filters=match_id IS NOT NULL, groupedBy=] RuntimeFilters: []

# %%
import pyspark.sql.functions as F
matches = matches.withColumn("obs_year", F.year("completion_date")).withColumn("obs_month",F.month("completion_date"))
matches.write.format("iceberg").partitionBy("obs_year","obs_month").mode("overwrite").saveAsTable("nessie.demo.fact_matches")

# %%
spark.table("nessie.demo.fact_matches").show(5,False)
# Out:
# +------------------------------------+------------------------------------+------------+------------------------------------+------------------------------------+-------------+-------------------+--------------+---------+--------------+--------+---------+
# |match_id                            |mapid                               |is_team_game|playlist_id                         |game_variant_id                     |is_match_over|completion_date    |match_duration|game_mode|map_variant_id|obs_year|obs_month|
# +------------------------------------+------------------------------------+------------+------------------------------------+------------------------------------+-------------+-------------------+--------------+---------+--------------+--------+---------+
# |38ab8397-0ebf-4a13-b784-2ec814de5e24|cb914b9e-f206-11e4-b447-24be05e24f7e|true        |892189e9-d712-4bdb-afa7-1ccab43fbed4|257a305e-4dd3-41f1-9824-dfe7e8bd59e1|true         |2016-09-01 00:00:00|NULL          |NULL     |NULL          |2016    |9        |
# |505fff80-4ff8-4617-8093-1c926f4048fc|cd844200-f206-11e4-9393-24be05e24f7e|true        |892189e9-d712-4bdb-afa7-1ccab43fbed4|257a305e-4dd3-41f1-9824-dfe7e8bd59e1|true         |2016-09-01 00:00:00|NULL          |NULL     |NULL          |2016    |9        |
# |022ee067-54dc-4061-8911-e8ae76eca93d|cdb934b0-f206-11e4-8810-24be05e24f7e|true        |892189e9-d712-4bdb-afa7-1ccab43fbed4|257a305e-4dd3-41f1-9824-dfe7e8bd59e1|true         |2016-09-01 00:00:00|NULL          |NULL     |NULL          |2016    |9        |
# |fde44002-138c-4b94-a6df-418e81ab8146|cebd854f-f206-11e4-b46e-24be05e24f7e|true        |892189e9-d712-4bdb-afa7-1ccab43fbed4|257a305e-4dd3-41f1-9824-dfe7e8bd59e1|true         |2016-09-01 00:00:00|NULL          |NULL     |NULL          |2016    |9        |
# |8cd42de3-6702-4f7b-8a9b-b9677bd78899|cd844200-f206-11e4-9393-24be05e24f7e|true        |892189e9-d712-4bdb-afa7-1ccab43fbed4|257a305e-4dd3-41f1-9824-dfe7e8bd59e1|true         |2016-09-01 00:00:00|NULL          |NULL     |NULL          |2016    |9        |
# +------------------------------------+------------------------------------+------------+------------------------------------+------------------------------------+-------------+-------------------+--------------+---------+--------------+--------+---------+
# only showing top 5 rows

# %%
# run compaction on the fact_matches table
spark.sql("CALL nessie.system.rewrite_data_files('nessie.demo.fact_matches')").show(5,False)
# Out:
# +--------------------------+----------------------+---------------------+-----------------------+
# |rewritten_data_files_count|added_data_files_count|rewritten_bytes_count|failed_data_files_count|
# +--------------------------+----------------------+---------------------+-----------------------+
# |0                         |0                     |0                    |0                      |
# +--------------------------+----------------------+---------------------+-----------------------+

# %%
# spark.sql("CALL nessie.system.expire_snapshots('nessie.demo.fact_matches')").show(5, False)
# spark.sql("ALTER TABLE nessie.demo.fact_matches SET TBLPROPERTIES ('gc.enabled'='true')")
spark.sql("CALL nessie.system.expire_snapshots('nessie.demo.fact_matches')").show(5, False)
# Out:
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
# |deleted_data_files_count|deleted_position_delete_files_count|deleted_equality_delete_files_count|deleted_manifest_files_count|deleted_manifest_lists_count|deleted_statistics_files_count|
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
# |0                       |0                                  |0                                  |0                           |0                           |0                             |
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
